# %%
# Out:
# Package                  Version    Editable project location
# ------------------------ ---------- ----------------------------------
# aiofiles                 22.1.0
# aiohttp                  3.8.4
# aiosignal                1.3.1
# aiosqlite                0.19.0
# alembic                  1.10.2
# antlr4-python3-runtime   4.9.3
# anyio                    3.6.2
# appdirs                  1.4.4
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# ascent                   0.1.0      /home/bernard/workspace/git/ASCENT
# asttokens                2.2.1
# async-timeout            4.0.2
# attrs                    22.2.0
# autopage                 0.5.1
# Babel                    2.12.1
# backcall                 0.2.0
# beautifulsoup4           4.12.2
# bleach                   6.0.0
# bokeh                    2.4.3
# certifi                  2022.12.7
# cffi                     1.15.1
# cfgv                     3.3.1
# ...
